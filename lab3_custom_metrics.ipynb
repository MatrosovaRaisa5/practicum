# %% [markdown]
# # Метрики

# %% [markdown]
# ![Метрики](https://avatars.mds.yandex.net/i?id=2e5e069d70098b486768047924a6b0b9578edc6d-8240464-images-thumbs&ref=rim&n=33&w=480&h=190)

# %%
def calculate_metrics(y_true, y_pred):
    TP = 0
    TN = 0
    FP = 0
    FN = 0

    for true, pred in zip(y_true, y_pred):
        if true == 1:
            if pred == 1:
                TP += 1
            else:
                FN += 1
        else:
            if pred == 0:
                TN += 1
            else:
                FP += 1

    # Матрица ошибок
    confusion_matrix = {
        'TP': TP,
        'TN': TN,
        'FP': FP,
        'FN': FN
    }

    # Расчет метрик с проверкой деления на ноль
    accuracy = (TP + TN) / (TP + TN + FP + FN) if (TP + TN + FP + FN) != 0 else 0.0
    precision = TP / (TP + FP) if (TP + FP) != 0 else 0.0
    recall = TP / (TP + FN) if (TP + FN) != 0 else 0.0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) != 0 else 0.0

    metrics = {
        'confusion_matrix': confusion_matrix,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1
    }

    return metrics
